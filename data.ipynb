# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv('movies.csv')
df = df.dropna()
df = df[["movie_name", "year_of_release", "genre"]]
df
# Out:
#                                         movie_name year_of_release  \
# 0                                    The Godfather          (1972)
# 1                         The Silence of the Lambs          (1991)
# 2   Star Wars: Episode V - The Empire Strikes Back          (1980)
# 3                         The Shawshank Redemption          (1994)
# 4                                      The Shining          (1980)
# ..                                             ...             ...
# 94                              The Usual Suspects          (1995)
# 95                                  Cool Hand Luke          (1967)
# 96           Eternal Sunshine of the Spotless Mind          (2004)
# 97                                     City Lights          (1931)
# 98                                      The Matrix          (1999)
#
#                          genre
# 0                 Crime, Drama
# 1       Crime, Drama, Thriller
# 2   Action, Adventure, Fantasy
# 3                        Drama
# ...

# %%
df['genre'].value_counts().head(10).plot(kind='pie', subplots=True, autopct='%1.0f%%', figsize=(9,9), title='Top 10 Genres From IMDB Top 100')
# Out:
# array([<AxesSubplot:ylabel='genre'>], dtype=object)
